# %%
import pandas as pd
from googletrans import Translator

def translate_csv(input_file, output_file, source_col_index):
    """
    Translate specific column content in a CSV file to English while maintaining original format.
    
    Parameters:
        input_file (str): Path to the input CSV file.
        output_file (str): Path to save the translated CSV file.
        source_col_index (int): The index of the column to translate (zero-based).
    """
    # Initialize translator
    translator = Translator()
    
    # Load CSV
    data = pd.read_csv(input_file, header=None)  # Assuming no header in CSV

    # Translate specific column
    translated_col = []
    for text in data.iloc[:, source_col_index]:
        try:
            # Translate text and add to the list
            translated_text = translator.translate(text, src='auto', dest='en').text
            translated_col.append(translated_text)
        except Exception as e:
            print(f"Error translating text: {text}, Error: {e}")
            translated_col.append(text)  # Keep original text in case of failure

    # Replace the column with translated content
    data.iloc[:, source_col_index] = translated_col
    
    # Save the result
    data.to_csv(output_file, index=False, header=False)
    print(f"Translated CSV saved to {output_file}")

# Input file path, output file path, and column index
input_csv = "output_123.csv"    # Replace with your input CSV file path
output_csv = "output_translate.csv"  # Replace with desired output CSV file path
column_to_translate = 7    # Replace with the column index to translate (zero-based)

translate_csv(input_csv, output_csv, column_to_translate)
# Out:
# Translated CSV saved to output_translate.csv

# %%
import pandas as pd
from googletrans import Translator
import ast  # 用于解析字符串为列表

def translate_hashtags(input_file, output_file, source_col_index):
    """
    Translate hashtag content in a specific column of a CSV file to English while maintaining original format.
    
    Parameters:
        input_file (str): Path to the input CSV file.
        output_file (str): Path to save the translated CSV file.
        source_col_index (int): The index of the column containing hashtags (zero-based).
    """
    translator = Translator()
    
    # Load CSV
    data = pd.read_csv(input_file, header=None)  # Assuming no header in CSV

    # Translate hashtags
    def translate_tags(tag_list_str):
        try:
            # Convert string to list
            tag_list = ast.literal_eval(tag_list_str)
            # Translate each hashtag
            translated_tags = [
                f"#{translator.translate(tag[1:], src='auto', dest='en').text}" 
                if tag.startswith('#') else tag
                for tag in tag_list
            ]
            # Convert back to string
            return str(translated_tags)
        except Exception as e:
            print(f"Error translating tags: {tag_list_str}, Error: {e}")
            return tag_list_str  # Keep original text in case of failure

    # Apply translation to the specified column
    data.iloc[:, source_col_index] = data.iloc[:, source_col_index].apply(translate_tags)
    
    # Save the result
    data.to_csv(output_file, index=False, header=False)
    print(f"Translated CSV saved to {output_file}")

# Input file path, output file path, and column index
input_csv = "output_123.csv"   # Replace with your input CSV file path
output_csv = "output_translate_v2.csv"  # Replace with desired output CSV file path
column_to_translate = 7    # Replace with the column index to translate (zero-based)

translate_hashtags(input_csv, output_csv, column_to_translate)
# Out:
# Error translating tags: hashtag, Error: malformed node or string on line 1: <ast.Name object at 0x000002E227EECE80>
# Error translating tags: ['#bifesta', '#ビフェスタ', '#Bifesta_ZEROBASEONE', '#Bifesta_ZB1', '#ZB1と毎日うる落ち', '#ZEROBASEONE', '#ZB1', '#ゼベワン', '#제로베이스원', '#キャンペーン', '#コラボキャンペーン', '#キャンペーン応募', '#クレンジング', '#洗顔', '#スキンケア'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#邊追星學韓文', '#新西遊記', '#신서유기', '#姜虎東', '#李秀根', '#殷志源', '#圭賢', '#宋旻浩', '#表志勳', '#강호동', '#이수근', '#은지원', '#규현', '#송민호', '#mino', '#표지훈', '#po', '#韓文學習', '#韓文', '#韓綜', '#韓文單字', '#學韓文', '#搞笑', '#搞笑影片', '#rollerskates', '#扇子', '#麥克風', '#funny', '#funnyvideos'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerobaseone', '#shenquanrui', '#ricky', '#zb1ricky', '#rickyzb1', '#zerobaseonericky', '#rickyzerobaseone', '#kpop', '#kpopfunny', '#zb1funny', '#zb1cute', '#5thgenkpop', '#5thgen', '#idol1nd2', '#zb1comeback', '#goodsobad', '#zerobaseone_goodsobad'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#BABYMONSTER', '#베이비몬스터', '#DRIP', '#DRIP_Challenge', '#kpop', '#dance', '#dancebreak', '#dancecover', '#댄스', '#부산댄스', '#댄스수업', '#tutorial', '#reels'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#한유진', '#HANYUJIN', '#보이즈플래닛', '#BoysPlanet', '#zerobaseone', '#zb1', '#HANYUJIN', '#한유진', '#ZEROBASEONE', '#ZB1', '#제로베이스원'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#台中美甲', '#逢甲美甲', '#西屯美甲', '#nails', '#gelnails', '#凝膠', '#凝膠指甲', '#凝膠暈染', '#台中美甲工作室', '#聖誕美甲', '#聖誕節美甲', '#秋冬美甲', '#白色系美甲', '#christmas', '#christmasnails', '#christmasnailart'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZEROBASEONE', '#ZB1', '#제로베이스원', '#SUNGHANBIN', '#ソンハンビン', '#성한빈', '#成韓彬', '#冰冰'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerobaseone', '#shenquanrui', '#ricky', '#zb1ricky', '#rickyzb1', '#zerobaseonericky', '#rickyzerobaseone', '#kpop', '#kpopfunny', '#zb1funny', '#zb1cute', '#5thgenkpop', '#5thgen', '#idol1nd2', '#zb1comeback', '#goodsobad', '#zerobaseone_goodsobad'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#GSメルティングバーム', '#ハグピンク', '#GSメルティングバーム', '#ETUDE', '#RIIZE', '#ETUDERIIZE', '#ETUDExRIIZE', '#HolidayCollection', '#DearMyBestie', '#Lipbalm', '#EUNSEOK', '#エチュード', '#ディアマイベスティ', '#ホリデーコレクション', '#リップバーム', '#ウンソク'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#aespa', '#에스파', '#karina', '#카리나'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#消水腫', '#濕氣', '#祛濕', '#提臀', '#上班族', '#核心', '#瘦腰', '#消脂', '#便秘', '#月經不調', '#消化不良', '#益生菌', '#女性', '#產後', '#台中', '#雙11'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#黑白大廚', '#netflixhk', '#netflixkr', '#흑백요리사_요리계급전쟁', '#CulinaryClassWars', '#koreatravel', '#koreatrip', '#hkfoodie', '#hktravel', '#hktravelblogger', '#韓國旅行'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#gummy', '#gummybears', '#viral', '#recipe'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ShenQuanrui', '#lovelicky', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop', '#Only_One_Story', '#ZEROBASEONE_OnlyOneStory', '#クワッス', '#Pokémon'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#厚鬆餅漢堡', '#宅配美食', '#團購美食', '#團購中', '#angel的麥當勞全攻略', '#angel熱量表實用外食系列', '#鬆餅漢堡', '#麥當勞鬆餅漢堡', '#麥當勞', '#麥當當', '#早餐吃什麼', '#麥當勞報報', '#新品報報', '#麥當勞新品', '#飲食控制', '#熱量控制', '#熱量計算', '#外食族', '#桃園美食', '#台北美食', '#新竹美食', '#台中美食', '#台南美食', '#高雄美食', '#新北美食', '#全台美食'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#宮崎駿', '#吉卜力', '#華山宮崎駿', '#吉卜力展覽', '#中壢美甲', '#桃園美甲', '#雙北美甲', '#魔女宅急便', '#神隱少女', '#霍爾的移動城堡', '#卡西法', '#魔法公主', '#手繪美甲', '#純手繪', '#痛甲', '#無臉男', '#波妞', '#龍貓', '#語錄分享', '#電影語錄', '#動畫推薦'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#麥當勞', '#新品', '#薯條', '#新竹美食', '#彰化美食', '#桃園美食', '#新北美食', '#台中美食', '#台南美食', '#台北美食', '#高雄美食', '#Mcdonalds', '#嘉義美食', '#彰化美食', '#宜蘭美食', '#南投美食', '#日本', '#日本美食', '#冰沙', '#草莓', '#巧克力'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#shorts', '#kpop', '#kpopdance', '#zb1', '#zerobaseone', '#kimjiwoong', '#김지웅', '#キムジウン', '#제베원', '#제로베이스원', '#12', '#11', '#10', '#09', '#08', '#07', '#06', '#아육대', '#아이돌', '#2024아육대', '#아육대양궁', '#아육대레전드', '#레전드', '#양궁', '#엑스텐'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#雖然沒準備什麼菜', '#차린건쥐뿔도없지만', '#이영지', '#txt', '#twice', '#kpopidol', '#韓綜'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#Timeleft', '#聚會神器', '#輕鬆約飯', '#認識新朋友', '#現實交友體驗', '#聚餐不用煩惱', '#社交新體驗', '#線上交友不如見面', '#Timeleft聚餐'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#KIMJIWOONG', '#bifesta', '#ビフェスタ', '#Bifesta_ZEROBASEONE', '#Bifesta_ZB1', '#ZB1と毎日うる落ち', '#ZEROBASEONE', '#ZB1', '#ゼベワン', '#제로베이스원', '#キムジウン', '#김지웅', '#クレンジング', '#クレンジングウォーター', '#スキンケア'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#穿戴甲', '#穿戴甲訂製', '#客製化美甲', '#美甲作品', '#台北美甲', '#台北穿戴甲', '#凝膠彩繪', '#凝膠設計', '#nail', '#nails', '#nailart', '#qgirlnail'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#한국', '#한국어', '#한국예능', '#예능', '#좋아요', '#일상', '#한국어공부', '#youtube', '#video', '#instagram', '#韓國', '#韓綜', '#影片'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#한유진', '#HANYUJIN', '#보이즈플래닛', '#BoysPlanet', '#zerobaseone', '#zb1', '#HANYUJIN', '#한유진', '#ZEROBASEONE', '#ZB1', '#제로베이스원'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#babymonster', '#ahyeon', '#정아현', '#아현', '#鄭雅譞', '#jungahyeon', '#ahyeon的向日葵', '#鄭雅賢'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#秋コーデ', '#秋服', '#シンプルコーデ', '#韓国ファッション', '#韓国コーデ', '#カジュアルコーデ', '#ストリートコーデ', '#ストリートファッション', '#秋冬コーデ', '#zozotown', '#外苑前いちょう並木'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#제로베이스원_존재자체가_GRAND', '#KGMA2024', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#dontoliver', '#nopole', '#dancechallenge', '#tiktokdance', '#lewkin', '#lewkiss'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#沈泉锐优时颜时光代言人', '#优时颜', '#优时颜黑引力面霜', '#每一面都是理想型', '#理想型', '#RICKY', '#沈泉锐', '#리키', '#ZB1', '#zerobaseone'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ive', '#아이브', '#gaeul', '#yujin', '#rei', '#wonyoung', '#liz', '#leeseo', '#kpop', '#idol'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#춤', '#원데이', '#원데이클래스', '#릴스', '#댄스레슨', '#취미댄스', '#케이팝', '#커버댄스', '#reels', '#댄스챌린지', '#reelsinstagram', '#dancechallenge', '#kpop', '#viviz', '#shhh', '#비비지', '#사당'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#shorts', '#kpop', '#kpopdance', '#zb1', '#zerobaseone', '#kimjiwoong', '#김지웅', '#キムジウン', '#제베원', '#제로베이스원', '#12', '#11', '#10', '#09', '#08', '#07', '#06', '#아육대', '#아이돌', '#2024아육대', '#아육대양궁', '#아육대레전드', '#레전드', '#양궁', '#엑스텐'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#txt', '#崔秀彬', '#수빈', '#soobin', '#kara', '#朴奎俐', '#규리', '#kpop', '#idol'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#台中美甲', '#逢甲美甲', '#西屯美甲', '#nails', '#gelnails', '#凝膠', '#凝膠指甲', '#凝膠暈染', '#台中美甲工作室', '#聖誕美甲', '#聖誕節美甲', '#秋冬美甲', '#白色系美甲', '#christmas', '#christmasnails', '#christmasnailart'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#한유진', '#HANYUJIN', '#보이즈플래닛', '#BoysPlanet', '#zerobaseone', '#zb1', '#HANYUJIN', '#한유진', '#ZEROBASEONE', '#ZB1', '#제로베이스원'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#美國', '#失憶', '#愛情', '#am730'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ShenQuanrui', '#lovelicky', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop', '#Only_One_Story', '#ZEROBASEONE_OnlyOneStory', '#クワッス', '#Pokémon'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#gidle', '#idle', '#shuhua', '#miyeon', '#yuqi', '#minnie', '#soyeon', '#孩子們', '#여자아이들', '#舒華', '#葉舒華', '#薇娟', '#雨琦', '#金米妮', '#田小娟', '#아이들', '#슈화', '#수진', '#미연', '#민니', '#소연', '#우기'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#人氣歌謠', '#인기가요', '#inkigayo', '#ZB1', '#ZEROBASEONE', '#제로베이스원', '#hanyujin', '#한유진', '#韓維辰', '#維辰', '#波多MC的工作日記', '#뽀돌엠씨', '#韓小兔美照來襲', '#사랑한유진'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#춤', '#원데이', '#원데이클래스', '#릴스', '#댄스레슨', '#취미댄스', '#케이팝', '#커버댄스', '#reels', '#댄스챌린지', '#reelsinstagram', '#dancechallenge', '#kpop', '#viviz', '#shhh', '#비비지', '#사당'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#shorts', '#kpop', '#kpopdance', '#zb1', '#zerobaseone', '#kimjiwoong', '#김지웅', '#キムジウン', '#제베원', '#제로베이스원', '#12', '#11', '#10', '#09', '#08', '#07', '#06', '#아육대', '#아이돌', '#2024아육대', '#아육대양궁', '#아육대레전드', '#레전드', '#양궁', '#엑스텐'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#弘第', '#弘第25', '#弘第二五閃耀綻放', '#公益商品', '#韓國藝匠', '#趙娟週', '#啦啦隊'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerose', '#zerobaseone', '#zerobaseone_goodsobad', '#goodsobad', '#timeless_world_tour', '#sunghanbin', '#ricky', '#shenquanrui', '#zb1leader', '#zerobaseoneleader', '#zb1ricky', '#rickyzb1', '#hanbin', '#hanbinzb1', '#hanbinsung', '#zb1sunghanbin', '#zb1cute', '#kpop', '#5thgenkpop'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#台中美甲', '#逢甲美甲', '#西屯美甲', '#nails', '#gelnails', '#凝膠', '#凝膠指甲', '#凝膠暈染', '#台中美甲工作室', '#聖誕美甲', '#聖誕節美甲', '#秋冬美甲', '#白色系美甲', '#christmas', '#christmasnails', '#christmasnailart'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#Dcard', '#YOYOTV', '#南瓜哥哥', '#帥哥', '#小車銀優', '#造咖'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ShenQuanrui', '#lovelicky', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop', '#Only_One_Story', '#ZEROBASEONE_OnlyOneStory', '#クワッス', '#Pokémon'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#gidle', '#idle', '#shuhua', '#miyeon', '#yuqi', '#minnie', '#soyeon', '#孩子們', '#여자아이들', '#舒華', '#葉舒華', '#薇娟', '#雨琦', '#金米妮', '#田小娟', '#아이들', '#슈화', '#수진', '#미연', '#민니', '#소연', '#우기'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#춤', '#원데이', '#원데이클래스', '#릴스', '#댄스레슨', '#취미댄스', '#케이팝', '#커버댄스', '#reels', '#댄스챌린지', '#reelsinstagram', '#dancechallenge', '#kpop', '#viviz', '#shhh', '#비비지', '#사당'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#한국', '#한국어', '#한국예능', '#예능', '#좋아요', '#일상', '#한국어공부', '#youtube', '#video', '#instagram', '#韓國', '#韓綜', '#影片'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#弘第', '#弘第25', '#弘第二五閃耀綻放', '#公益商品', '#韓國藝匠', '#趙娟週', '#啦啦隊'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerose', '#zerobaseone', '#zerobaseone_goodsobad', '#goodsobad', '#timeless_world_tour', '#sunghanbin', '#ricky', '#shenquanrui', '#zb1leader', '#zerobaseoneleader', '#zb1ricky', '#rickyzb1', '#hanbin', '#hanbinzb1', '#hanbinsung', '#zb1sunghanbin', '#zb1cute', '#kpop', '#5thgenkpop'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#김태래', '#태래', '#멯', '#제로베이스원', '#제베원', '#KIMTAERAE', '#TAERAE', '#金泰來', '#ZEROBASEONE', '#ZB1', '#ZB1HK', '#성한빈', '#SUNGHANBIN'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#拉拉台', '#LalaTai', '#lesbian', '#女同志', '#lgbtq', '#gl劇', '#泰劇', '#百合', '#女女cp', '#faymay'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#Noah', '#niusnews', '#妞新聞', '#黑白大廚', '#Netflix'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZEROBASEONE', '#ZB1', '#제로베이스원', '#김태래', '#KIMTAERAE', '#キムテレ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#黑白大廚', '#netflixhk', '#netflixkr', '#흑백요리사_요리계급전쟁', '#CulinaryClassWars', '#koreatravel', '#koreatrip', '#hkfoodie', '#hktravel', '#hktravelblogger', '#韓國旅行'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#StrayKids', '#스트레이키즈', '#dominATE', '#dominATE_KAOHSIUNG', '#ATE', '#ChkChkBoom', '#youmakestraykidsstay', '#李龍馥', '#felix', '#필릭스', '#ピリ', '#bbokari', '#ポガリ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#搞笑', '#搞笑綜藝', '#綜藝', '#有趣', '#幽默', '#梗', '#影片', '#搞笑影片', '#影片分享'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#사쿠라다켄신', '#빙화', '#백지호', '#박찬용', '#박준우', '#박준서', '#마징시앙', '#마나베진', '#린웨이천', '#린린', '#남지운', '#김현재', '#김현우', '#김태유', '#김태성', '#김지환', '#김지민', '#김준우', '#김주현', '#김정윤', '#PROJECT7', '#프로젝트7', '#Assemble', '#Upgrade', '#WorldAssembler', '#Lets_Assemble', '#JTBC', '#SLL'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#章昊', '#장하오', '#ZHANGHAO', '#ZB1', '#ZEROBASEONE', '#kustie'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#bts', '#kpop', '#kpopmemes', '#金碩珍', '#鄭號錫', '#金泰享', '#金南俊', '#田柾國', '#閔玧其', '#朴智旻', '#army', '#防彈少年團', '#btsmemes', '#奔跑吧防彈', '#runbts', '#jungkook', '#jin', '#suga', '#v', '#jimin', '#rm', '#jhope'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#kate', '#怪獸唇膏', '#G03'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#黑白大廚', '#netflixhk', '#netflixkr', '#흑백요리사_요리계급전쟁', '#CulinaryClassWars', '#koreatravel', '#koreatrip', '#hkfoodie', '#hktravel', '#hktravelblogger', '#韓國旅行'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZEROBASEONE', '#ZB1', '#제로베이스원', '#김태래', '#KIMTAERAE', '#キムテレ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#StrayKids', '#스트레이키즈', '#dominATE', '#dominATE_KAOHSIUNG', '#ATE', '#ChkChkBoom', '#youmakestraykidsstay', '#李龍馥', '#felix', '#필릭스', '#ピリ', '#bbokari', '#ポガリ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#사쿠라다켄신', '#빙화', '#백지호', '#박찬용', '#박준우', '#박준서', '#마징시앙', '#마나베진', '#린웨이천', '#린린', '#남지운', '#김현재', '#김현우', '#김태유', '#김태성', '#김지환', '#김지민', '#김준우', '#김주현', '#김정윤', '#PROJECT7', '#프로젝트7', '#Assemble', '#Upgrade', '#WorldAssembler', '#Lets_Assemble', '#JTBC', '#SLL'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#thenanny', '#天才保姆', '#美劇'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#퓌', '#fwee', '#푸딩팟', '#푸딩팟쿨부산', '#puddingpot', '#fweeAgitbusan', '#퓌아지트부산'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#人氣歌謠', '#인기가요', '#inkigayo', '#ZB1', '#ZEROBASEONE', '#제로베이스원', '#hanyujin', '#한유진', '#韓維辰', '#維辰', '#波多MC的工作日記', '#뽀돌엠씨', '#韓小兔美照來襲', '#사랑한유진'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#章昊', '#장하오', '#ZHANGHAO', '#ZB1', '#ZEROBASEONE', '#kustie'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#아이브', '#IVE', '#가을', '#GAEUL', '#유진', '#YUJIN', '#레이', '#REI', '#원영', '#WONYOUNG', '#리즈', '#LIZ', '#이서', '#LEESEO'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#lunluninkr', '#黑白大廚', '#黑白大廚探店趣', '#首爾美食', '#鄭智善', '#甜蜜蜜'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#shebeauty', '#Minji', '#newjeans', '#newjeansminji', '#minjinewjeans', '#김민지', '#金玟池', '#KimMinji'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#實習懶人包', '#線上課', '#行政助理', '#庶務管理', '#行政人員', '#訓練規劃', '#軟體開發', '#產品測試', '#資安軟體開發', '#網路安全', '#軟體測試', '#線上課程', '#內容企劃', '#創意發想', '#公關助理', '#品牌行銷', '#流程優化', '#Python', '#大學', '#實習計畫', '#懶人包', '#乾貨', '#職涯', '#大學生活', '#實習', '#實習生', '#工作', '#補帖', '#starroad'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#搞笑', '#搞笑綜藝', '#綜藝', '#有趣', '#幽默', '#梗', '#影片', '#搞笑影片', '#影片分享'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#首爾小隊', '#黑白大廚', '#黑白大廚料理階級大戰', '#黑白大廚餐廳', '#黑白大廚探店趣', '#흑백요리사', '#흑백요리사식당'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZHANGHAO', '#zb1zhanghao', '#ZB1', '#ZEROBASEONE', '#장하오', '#sunghanbin', '#seokmatthew', '#ricky', '#parkgunwook', '#kimjiwoong', '#kimgyuvin', '#kimjiwoong', '#hanyujin'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#dontoliver', '#nopole', '#dancechallenge', '#tiktokdance', '#lewkin', '#lewkiss'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#搞笑', '#搞笑綜藝', '#綜藝', '#有趣', '#幽默', '#梗', '#影片', '#搞笑影片', '#影片分享'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ネイル', '#ネイルチッフ', '#ネイルチッフ', '#ネイルチッフ', '#冬ネイル', '#ブラウンネイル', '#ゆめかわいい', '#手書きネイル', '#ベージュネイル', '#ゆめかわいい人と繋か', '#リボンネイル', '#可愛い', '#可愛いネイル', '#可愛いもの好きな人と繋か', '#オシャレさんと繋がりたい', '#アートネイル', '#かくしきれないヲタク', '#落書きネイル', '#隠しきれないヲタク', '#くまさんネイル', '#3dネイル', '#ガーリー', '#秋ネイル', '#水色ネイル', '#クリスマスネイル', '#nailart', '#ツイードネイル', '#ニットネイル', '#推しのいる生活', '#ガーリーネイル'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerose', '#zerobaseone', '#zerobaseone_goodsobad', '#goodsobad', '#timeless_world_tour', '#sunghanbin', '#ricky', '#shenquanrui', '#zb1leader', '#zerobaseoneleader', '#zb1ricky', '#rickyzb1', '#hanbin', '#hanbinzb1', '#hanbinsung', '#zb1sunghanbin', '#zb1cute', '#kpop', '#5thgenkpop'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#japantravel', '#日本必買', '#uniqloコーデ', '#gu', '#tutuanna', '#大國藥妝', '#日本藥妝', '#biccamera', '#loftjapan', '#aeonmall', '#costcojapan', '#唐吉軻德', '#激安スーパー', '#lawson', '#dhcjapan', '#波波日本', '#ling', '#klooktravel', '#好想去日本'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#台北美甲', '#暈染美甲', '#灰色美甲', '#藍色美甲', '#白色美甲', '#蝴蝶結美甲', '#暈染', '#行天宮美甲', '#士林美甲', '#劍潭美甲', '#三重美甲', '#蘆洲美甲', '#小紅書美甲', '#西門町美甲', '#西門美甲', '#小紅書', '#氣質美甲', '#溫柔美甲', '#上班族美甲'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#jennie', '#mantra', '#제니', '#reels'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#personality', '#glasses', '#BodyLanguage', '#眼镜', '#推眼镜', '#性格', '#识人术', '#就酱Young'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#bts', '#kpop', '#kpopmemes', '#金碩珍', '#鄭號錫', '#金泰享', '#金南俊', '#田柾國', '#閔玧其', '#朴智旻', '#army', '#防彈少年團', '#btsmemes', '#奔跑吧防彈', '#runbts', '#jungkook', '#jin', '#suga', '#v', '#jimin', '#rm', '#jhope'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#kate', '#怪獸唇膏', '#G03'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZEROBASEONE', '#ZB1', '#제로베이스원', '#김태래', '#KIMTAERAE', '#キムテレ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#StrayKids', '#스트레이키즈', '#dominATE', '#dominATE_KAOHSIUNG', '#ATE', '#ChkChkBoom', '#youmakestraykidsstay', '#李龍馥', '#felix', '#필릭스', '#ピリ', '#bbokari', '#ポガリ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#사쿠라다켄신', '#빙화', '#백지호', '#박찬용', '#박준우', '#박준서', '#마징시앙', '#마나베진', '#린웨이천', '#린린', '#남지운', '#김현재', '#김현우', '#김태유', '#김태성', '#김지환', '#김지민', '#김준우', '#김주현', '#김정윤', '#PROJECT7', '#프로젝트7', '#Assemble', '#Upgrade', '#WorldAssembler', '#Lets_Assemble', '#JTBC', '#SLL'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#aespa', '#Giselle', '#ILLIT', '#IROHA', '#韓國情報', '#韓國新聞', '#韓國流行', '#kpop', '#twice', '#lesserafim', '#izone', '#ive'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#消水腫', '#濕氣', '#祛濕', '#提臀', '#上班族', '#核心', '#瘦腰', '#消脂', '#便秘', '#月經不調', '#消化不良', '#益生菌', '#女性', '#產後', '#台中', '#雙11'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#迷因', '#memeallthetime', '#有趣', '#歡樂', '#開心', '#fyp', '#yoasobi', '#群青', '#台灣'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#StrayKids', '#스트레이키즈', '#dominATE', '#dominATE_KAOHSIUNG', '#ATE', '#ChkChkBoom', '#youmakestraykidsstay', '#李龍馥', '#felix', '#필릭스', '#ピリ', '#bbokari', '#ポガリ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#即新聞', '#結婚', '#婚禮', '#新郎', '#溫馨', '#親情', '#父子'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#黑白大廚', '#netflixhk', '#netflixkr', '#흑백요리사_요리계급전쟁', '#CulinaryClassWars', '#koreatravel', '#koreatrip', '#hkfoodie', '#hktravel', '#hktravelblogger', '#韓國旅行'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#聖誕節', '#聖誕節美甲', '#聖誕節', '#聖誕美甲', '#雪人美甲', '#christmasnails', '#christmasgelnails', '#christmas', '#手繪美甲', '#卡通美甲', '#色塊美甲', '#線條美甲', '#簡約美甲', '#文青美甲', '#手繪美甲', '#秋冬美甲', '#冬天美甲', '#秋天美甲', '#台北美甲', '#大橋頭美甲', '#圓山美甲', '#雙連美甲', '#民權西美甲', '#nails', '#nailsgel', '#nailsart'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#aespa', '#Giselle', '#ILLIT', '#IROHA', '#韓國情報', '#韓國新聞', '#韓國流行', '#kpop', '#twice', '#lesserafim', '#izone', '#ive'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#消水腫', '#濕氣', '#祛濕', '#提臀', '#上班族', '#核心', '#瘦腰', '#消脂', '#便秘', '#月經不調', '#消化不良', '#益生菌', '#女性', '#產後', '#台中', '#雙11'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#kate', '#怪獸唇膏', '#G03'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#迷因', '#memeallthetime', '#有趣', '#歡樂', '#開心', '#fyp', '#yoasobi', '#群青', '#台灣'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#崔顯旭', '#金秀賢'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#StrayKids', '#스트레이키즈', '#dominATE', '#dominATE_KAOHSIUNG', '#ATE', '#ChkChkBoom', '#youmakestraykidsstay', '#李龍馥', '#felix', '#필릭스', '#ピリ', '#bbokari', '#ポガリ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZEROBASEONE', '#ZB1', '#제로베이스원', '#김태래', '#KIMTAERAE', '#キムテレ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#黑白大廚', '#netflixhk', '#netflixkr', '#흑백요리사_요리계급전쟁', '#CulinaryClassWars', '#koreatravel', '#koreatrip', '#hkfoodie', '#hktravel', '#hktravelblogger', '#韓國旅行'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#聖誕節', '#聖誕節美甲', '#聖誕節', '#聖誕美甲', '#雪人美甲', '#christmasnails', '#christmasgelnails', '#christmas', '#手繪美甲', '#卡通美甲', '#色塊美甲', '#線條美甲', '#簡約美甲', '#文青美甲', '#手繪美甲', '#秋冬美甲', '#冬天美甲', '#秋天美甲', '#台北美甲', '#大橋頭美甲', '#圓山美甲', '#雙連美甲', '#民權西美甲', '#nails', '#nailsgel', '#nailsart'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#퓌', '#fwee', '#푸딩팟', '#푸딩팟쿨부산', '#puddingpot', '#fweeAgitbusan', '#퓌아지트부산'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#dance', '#fyp', '#kpop', '#babymonster', '#drip', '#cover'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#personality', '#glasses', '#BodyLanguage', '#眼镜', '#推眼镜', '#性格', '#识人术', '#就酱Young'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#aespa', '#Giselle', '#ILLIT', '#IROHA', '#韓國情報', '#韓國新聞', '#韓國流行', '#kpop', '#twice', '#lesserafim', '#izone', '#ive'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#消水腫', '#濕氣', '#祛濕', '#提臀', '#上班族', '#核心', '#瘦腰', '#消脂', '#便秘', '#月經不調', '#消化不良', '#益生菌', '#女性', '#產後', '#台中', '#雙11'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#XG', '#HOWLING', '#XGLAX', '#dance', '#dancechallenge', '#reels', '#XG_HOWLING'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#kate', '#怪獸唇膏', '#G03'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#拉拉台', '#LalaTai', '#lesbian', '#女同志', '#lgbtq', '#gl劇', '#泰劇', '#百合', '#女女cp', '#faymay'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#迷因', '#memeallthetime', '#有趣', '#歡樂', '#開心', '#fyp', '#yoasobi', '#群青', '#台灣'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#StrayKids', '#스트레이키즈', '#dominATE', '#dominATE_KAOHSIUNG', '#ATE', '#ChkChkBoom', '#youmakestraykidsstay', '#李龍馥', '#felix', '#필릭스', '#ピリ', '#bbokari', '#ポガリ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZEROBASEONE', '#ZB1', '#제로베이스원', '#김태래', '#KIMTAERAE', '#キムテレ'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#aespa', '#에스파'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#shebeauty', '#黑白大廚', '#Netflix', '#鄭智善', '#眼線', '#眼線筆', '#眼妝'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#蘇打綠', '#sodagreen', '#蘇打綠', '#蘇打綠二十年一刻巡迴演唱會', '#sodagreen', '#20thAnniversaryConcertTour'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#水果', '#水果吃法', '#挑戰'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#PRADAxGYUVIN', '#PRADAxMATTHEW', '#PRADAxRICKY', '#SoundofPrada', '#TheSoundOfPradaSeoul', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop', '#Only_One_Story', '#ZEROBASEONE_OnlyOneStory'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#時分主題設計不做第二次', '#時分美甲', '#手繪', '#可愛美甲', '#凝膠', '#凝膠指甲', '#指甲彩繪', '#台北美甲', '#萬華美甲', '#nails', '#nailart', '#naildesign', '#nails', '#instanails', '#manicure', '#gelnails', '#uñas', '#uñasacrilicas', '#uñasdecoradas', '#Unhas', '#네일', '#네일아트', '#네일그램', '#네일그타그램', '#ネイルアート', '#ネイルデザイン', '#ongles', '#nägel', '#nagellack', '#เล'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerobaseone', '#shenquanrui', '#ricky', '#zb1ricky', '#rickyzb1', '#zerobaseonericky', '#rickyzerobaseone', '#kpop', '#kpopfunny', '#zb1funny', '#zb1cute', '#5thgenkpop', '#5thgen', '#idol1nd2', '#zb1comeback', '#goodsobad', '#zerobaseone_goodsobad'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#搞笑', '#搞笑綜藝', '#綜藝', '#有趣', '#幽默', '#梗', '#影片', '#搞笑影片', '#影片分享'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#1117', '#sunghoon', '#parksunghoon', '#enhypen', '#박성훈', '#성훈', '#엔하이픈', '#Jungwon', '#enhypenhk', '#fff', '#成訓', '#朴成訓', '#禎元', '#enhypen小卡', '#enhypencollection', '#kpopcollection', '#kpopcollector', '#イルコン', '#enhypen好きな人と繋か', '#engeneと繋がりたい', '#engeneさんと繋がりたい'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZB1', '#ZEROBASEONE', '#제로베이스원', '#BOYSPLANET', '#보이즈플래닛', '#INSTACHILE', '#KPOP', '#WAKEONE', '#웨이크원엔터테인먼트', '#CINEMA_PARADISE', '#GOODSOBAD', '#ZEROBASEONE_GOODSOBAD', '#ZEROSE', '#ZE_ROSE'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#BABYMONSTER', '#베이비몬스터', '#DRIP', '#DRIP_Challenge', '#kpop', '#dance', '#dancebreak', '#dancecover', '#댄스', '#부산댄스', '#댄스수업', '#tutorial', '#reels'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#新竹', '#新竹美食', '#新竹景點', '#新竹咖啡廳', '#新竹甜點', '#可播兄弟'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#shebeauty', '#黑白大廚', '#Netflix', '#鄭智善', '#眼線', '#眼線筆', '#眼妝'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#黑白大廚'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#水果', '#水果吃法', '#挑戰'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#PRADAxGYUVIN', '#PRADAxMATTHEW', '#PRADAxRICKY', '#SoundofPrada', '#TheSoundOfPradaSeoul', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop', '#Only_One_Story', '#ZEROBASEONE_OnlyOneStory'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#時分主題設計不做第二次', '#時分美甲', '#手繪', '#可愛美甲', '#凝膠', '#凝膠指甲', '#指甲彩繪', '#台北美甲', '#萬華美甲', '#nails', '#nailart', '#naildesign', '#nails', '#instanails', '#manicure', '#gelnails', '#uñas', '#uñasacrilicas', '#uñasdecoradas', '#Unhas', '#네일', '#네일아트', '#네일그램', '#네일그타그램', '#ネイルアート', '#ネイルデザイン', '#ongles', '#nägel', '#nagellack', '#เล'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#蘿蔔糕'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#zb1', '#ZeroBaseOne', '#zerobaseone', '#shenquanrui', '#ricky', '#zb1ricky', '#rickyzb1', '#zerobaseonericky', '#rickyzerobaseone', '#kpop', '#kpopfunny', '#zb1funny', '#zb1cute', '#5thgenkpop', '#5thgen', '#idol1nd2', '#zb1comeback', '#goodsobad', '#zerobaseone_goodsobad'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#搞笑', '#搞笑綜藝', '#綜藝', '#有趣', '#幽默', '#梗', '#影片', '#搞笑影片', '#影片分享'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#1117', '#sunghoon', '#parksunghoon', '#enhypen', '#박성훈', '#성훈', '#엔하이픈', '#Jungwon', '#enhypenhk', '#fff', '#成訓', '#朴成訓', '#禎元', '#enhypen小卡', '#enhypencollection', '#kpopcollection', '#kpopcollector', '#イルコン', '#enhypen好きな人と繋か', '#engeneと繋がりたい', '#engeneさんと繋がりたい'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#ZB1', '#ZEROBASEONE', '#제로베이스원', '#BOYSPLANET', '#보이즈플래닛', '#INSTACHILE', '#KPOP', '#WAKEONE', '#웨이크원엔터테인먼트', '#CINEMA_PARADISE', '#GOODSOBAD', '#ZEROBASEONE_GOODSOBAD', '#ZEROSE', '#ZE_ROSE'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#BABYMONSTER', '#베이비몬스터', '#DRIP', '#DRIP_Challenge', '#kpop', '#dance', '#dancebreak', '#dancecover', '#댄스', '#부산댄스', '#댄스수업', '#tutorial', '#reels'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#新竹', '#新竹美食', '#新竹景點', '#新竹咖啡廳', '#新竹甜點', '#可播兄弟'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#蘇打綠', '#sodagreen', '#蘇打綠', '#蘇打綠二十年一刻巡迴演唱會', '#sodagreen', '#20thAnniversaryConcertTour'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#水果', '#水果吃法', '#挑戰'], Error: 'Translator' object has no attribute 'raise_Exception'
# Error translating tags: ['#PRADAxGYUVIN', '#PRADAxMATTHEW', '#PRADAxRICKY', '#SoundofPrada', '#TheSoundOfPradaSeoul', '#ZEROBASEONE', '#ZB1', '#제로베이스원', '#ZHANGHAO', '#장하오', '#sunghanbin', '#성한빈', '#seokmatthew', '#석매튜', '#ricky', '#리키', '#parkgunwook', '#박건욱', '#kimtaerae', '#김태래', '#kimgyuvin', '#김규빈', '#kimjiwoong', '#김지웅', '#hanyujin', '#한유진', '#kpop', '#Only_One_Story', '#ZEROBASEONE_OnlyOneStory'], Error: 'Translator' object has no attribute 'raise_Exception'
# Translated CSV saved to output_translate_v2.csv
